# %% [markdown]
# Create New API Token by going to profile page in kaggle to get kaggle.json

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
# Give the location of kaggle.json file where you uploaed the file in google drive or colab storage.
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Colab Notebooks/'

# %% [markdown]
# Copy API Command
# ![image.png](data:image/png;base64,...)

# %%
#! chmod 600 ~/.content/drive/MyDrive/Colab%Notebooks/kaggle.json

# %%
# !kaggle datasets download -d datamunge/sign-language-mnist
# Out:
# ...
#  78% 49.0M/62.6M [00:00<00:00, 51.8MB/s]
# 100% 62.6M/62.6M [00:00<00:00, 67.7MB/s]

# %%
#!cp /content/brats2020-trainval.zip /content/drive/MyDrive/BraTS/

# %%
# !unzip \*.zip && rm *.zip;
# Out:
# Archive:  sign-language-mnist.zip
#   inflating: amer_sign2.png
#   inflating: amer_sign3.png
#   inflating: american_sign_language.PNG
#   inflating: sign_mnist_test.csv
#   inflating: sign_mnist_test/sign_mnist_test.csv
#   inflating: sign_mnist_train.csv
#   inflating: sign_mnist_train/sign_mnist_train.csv
